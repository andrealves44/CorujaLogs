# %%
import pandas as pd

# %%
from google.colab import drive

# Montar o Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Verificar o conteúdo da pasta 'DadosComexStat'
import os

# Caminho da pasta no Google Drive
pasta_drive = '/content/drive/MyDrive/Data'

if os.path.exists(pasta_drive):
    arquivos = os.listdir(pasta_drive)
    print(f"{arquivos}")
else:
    print(f"Pasta não encontrada no Google Drive.")
# Out:
# ['API-3', 'RENAEST - Veículos', 'Dashboard Power BI', 'data15_24.csv', 'renaest2015_2024.csv', 'RENAEST_CSV', 'Tabela meses - anos.csv', 'data15_24_atualizado.csv']

# %%
arquivo_1 = '/content/drive/MyDrive/Data/renaest2015_2024.csv'

# %%
rena_15_24 = pd.read_csv(arquivo_1, sep=';', encoding='utf-8')

# %%
rena_15_24.head(10)
# Out:
#   Unidades da Federação      TOTAL  AUTOMÓVEL   BONDE  CAMINHÃO  \
# 0                 Acre     224.939     73.314    -        6.628
# 1                Amapá     166.003     69.827    -        3.934
# 2              Amazonas    760.059    346.762    -       19.667
# 3                 Pará   1.597.746    495.146    -       54.134
# 4             Rondônia     821.833    231.671    -       28.252
# 5               Roraima    179.925     58.815    -        4.165
# 6             Tocantins    576.053    174.953    -       21.640
# 7               Alagoas    676.035    297.999    -       19.931
# 8                 Bahia  3.445.891  1.536.625       3   111.127
# 9                 Ceará  2.611.384    960.458    -       65.491
#
#    CAMINHÃO TRATOR CAMINHONETE CAMIONETA CHASSI PLATAFORMA  CICLOMOTOR  ...  \
# 0          680.000      21.478     3.766                10     245.000  ...
# 1          289.000      18.139     3.962                14     838.000  ...
# ...

# %%
# Lê o arquivo CSV
rena_15_24 = pd.read_csv(arquivo_1, dtype=str, sep=';', encoding='utf-8')  # lê tudo como string para evitar erros de conversão

# Remove os pontos de todos os valores numéricos
rena_15_24 = rena_15_24.map(lambda x: x.replace('.', '') if isinstance(x, str) else x)

# (Opcional) Se quiser transformar de volta em números
# df = df.apply(pd.to_numeric, errors='ignore')

# Salva o resultado em um novo arquivo
rena_15_24.to_csv("Renaest_15-24_Corrigido.csv", index=False)

print("Pontos removidos com sucesso! Arquivo salvo como 'Renaest_15-24_Corrigido.csv'.")
# Out:
# Pontos removidos com sucesso! Arquivo salvo como 'Renaest_15-24_Corrigido.csv'.

# %%
rena_15_24.head(10)
# Out:
#   Unidades da Federação    TOTAL AUTOMÓVEL   BONDE CAMINHÃO CAMINHÃO TRATOR  \
# 0                 Acre    224939     73314    -        6628            6800
# 1                Amapá    166003     69827    -        3934            2890
# 2              Amazonas   760059    346762    -       19667            2893
# 3                 Pará   1597746    495146    -       54134            6628
# 4             Rondônia    821833    231671    -       28252            5561
# 5               Roraima   179925     58815    -        4165            5250
# 6             Tocantins   576053    174953    -        2164            4296
# 7               Alagoas   676035    297999    -       19931            2161
# 8                 Bahia  3445891   1536625       3   111127           19189
# 9                 Ceará  2611384    960458    -       65491             725
#
#   CAMINHONETE CAMIONETA CHASSI PLATAFORMA CICLOMOTOR  ... SEMI-REBOQUE  \
# ...

# %%
rena_15_24.to_csv('Renaest_15-24_Corrigido.csv', sep=';', encoding='UTF-8', index=False)

from google.colab import files

files.download('Renaest_15-24_Corrigido.csv')
